# %%
# %%writefile type_casting.c
#
# #include <stdio.h>
#
# int main() {
#   float f = 69.99;
#   int i = (int) f;
#   printf("%d\n", i);
#   char c = (char) i;
#   printf("%c\n", c);
# }
# Out:
# Writing type_casting.c

# %%
# !gcc type_casting.c -o type_casting
# !./type_casting
# Out:
# 69
# E
